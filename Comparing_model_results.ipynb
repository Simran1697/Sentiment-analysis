# %%
import pandas as pd

# %%
df1 = pd.read_csv("result_nb.csv")
df2 = pd.read_csv("result_rf.csv")
df3 = pd.read_csv("result_lg.csv")
df4 = pd.read_csv("result_sgd.csv")
df5 = pd.read_csv("result_xgb.csv")
df6 = pd.read_csv("result_svc.csv")

# %%
df1['Sentiment_rf'] = df2['Sentiment_rf']
df1['Sentiment_lg'] = df3['Sentiment_lg']
df1['Sentiment_sgd'] = df4['Sentiment_sgd']
df1['Sentiment_xgb'] = df5['Sentiment_xgb']
df1['Sentiment_svm'] = df6['Sentiment_svc']

# %%
df1
# Out:
#                                                     Tweet Sentiment_nb  \
# 0       bianca andreescu forced withdraw madrid open t...     Positive
# 1        farce last year recognizing handful talent cont…      Neutral
# 2       brazil records new coronavirus cases additiona...     Negative
# 3       akbarowaisimim one point praying iss wabah ka ...     Positive
# 4       uaetonight stand solidarity india prominent la...     Negative
# ...                                                   ...          ...
# 149983  nearly people localities received shots april ...     Negative
# 149984  ways fight must teach children right way right...     Positive
# 149985  ontario government house leader paul calandra ...     Positive
# 149986  dog really said glazersout indianeedsoxygen co...     Negative
# 149987  himanta biswa sarma mentioned assam sufficient...     Positive
#
#        Sentiment_rf Sentiment_lg Sentiment_sgd Sentiment_xgb Sentiment_svm
# ...
